# %%
from karel.stanfordkarel import *

"""
Karel should fill the whole world with beepers.
"""


def main():
    """
    You should write your code to make Karel do its task in
    this function. Make sure to delete the 'pass' line before
    starting to write your own code. You should also delete this
    comment and replace it with a better, more descriptive one.
    """
    fill_the_world()
    


def fill_the_world():
    for i in range(4):

        # first row
        facing_east()
        facing_west()
        move_up()
        turn_right()
    facing_east()



# Karel facing east to distribute beepers 
def facing_east():
    put_beeper()

    while front_is_clear():
        move()
        put_beeper()



# Karel returning it initial stage to restart again
def facing_west():
    turn_around()

    while front_is_clear():
        move()

def move_up():
    turn_right()
    move()

def turn_right():
    turn_left()
    turn_left()
    turn_left()
def turn_around():
    turn_left()
    turn_left()

# There is no need to edit code beyond this point
if __name__ == '__main__':
    main()

# %%
# first challenge without touching beepers

from karel.stanfordkarel import *

"""
Karel should fill the whole world with beepers.
"""


def main():
    """
    You should write your code to make Karel do its task in
    this function. Make sure to delete the 'pass' line before
    starting to write your own code. You should also delete this
    comment and replace it with a better, more descriptive one.
    """
    fill_the_world() # invoking the function for all the filling
    
# this function take care of the moving and filling
def fill_the_world():
    for i in range(4):
        facing_east()
        facing_west()
        turn_right()
        move_up()
    destination()



# last step for Karel erand
def destination():
    facing_east()
    facing_west()
    turn_around()
    while front_is_clear():
        move()


# when facing right and front is clear
def facing_east():
    while front_is_clear():
        move()

    turn_around()

# when facing left side and front is clear keep moving
def facing_west():
    put_beeper()

    while front_is_clear():
        move()
        put_beeper()

# turn twice AKA turn_around
def turn_around():
    for i in range(2):
        turn_left()
        
    
# turn trice AKA turn_right
def turn_right():
    for i in range(3):
        turn_left()

def move_up():
    move()
    turn_right()

# There is no need to edit code beyond this point
if __name__ == '__main__':
    main()
