# %%
# graphics
from graphics import Canvas
import random

CANVAS_WIDTH = 450
CANVAS_HEIGHT = 300

def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    for i in range(0, 5):
        canvas.create_oval(i*20, i*20, i*20+20, i*20+20)
    

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # graphics
# ----> 2 from graphics import Canvas
#       3 import random
#       5 CANVAS_WIDTH = 450
#
# ModuleNotFoundError: No module named 'graphics'

# %%
# quilt
from graphics import Canvas

# each patch is a square with this width and height:
PATCH_SIZE = 100
CANVAS_WIDTH = PATCH_SIZE * 4
CANVAS_HEIGHT = PATCH_SIZE * 2

def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    # draw the first row of patches
    draw_square_patch(canvas, 0, 0)
    draw_circle_patch(canvas, PATCH_SIZE, 0)
    draw_square_patch(canvas, PATCH_SIZE*2, 0)
    draw_circle_patch(canvas, PATCH_SIZE*3, 0)
    # TODO: your code here
    
def draw_circle_patch(canvas, start_x, start_y):
    # TODO: your code here
    pass

def draw_square_patch(canvas, start_x, start_y):
    # draws a purple frame at (start_x, start_y)
    end_x = start_x + PATCH_SIZE
    end_y = start_y + PATCH_SIZE
    inset = 20
    # first draw a purple square over the entire patch
    canvas.create_rectangle(start_x, start_y, end_x, end_y, 'purple')
    # then draw a smaller white square on top
    canvas.create_rectangle(start_x+inset, start_y+inset, 
        end_x-inset, end_y-inset, 'white')
    
if __name__ == '__main__':
    main()

# %%
from graphics import Canvas

# each patch is a square with this width and height:
PATCH_SIZE = 100
CANVAS_WIDTH = PATCH_SIZE * 4
CANVAS_HEIGHT = PATCH_SIZE * 2

def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    # draw the first row of patches
    draw_square_patch(canvas, 0, 0)
    draw_circle_patch(canvas, PATCH_SIZE, 0)
    draw_square_patch(canvas, PATCH_SIZE*2, 0)
    draw_circle_patch(canvas, PATCH_SIZE*3, 0)
    # TODO: your code here
    
def draw_circle_patch(canvas, start_x, start_y):
    # TODO: your code here
    pass

def draw_square_patch(canvas, start_x, start_y):
    # draws a purple frame at (start_x, start_y)
    end_x = start_x + PATCH_SIZE
    end_y = start_y + PATCH_SIZE
    inset = 20
    # first draw a purple square over the entire patch
    canvas.create_rectangle(start_x, start_y, end_x, end_y, 'purple')
    # then draw a smaller white square on top
    canvas.create_rectangle(start_x+inset, start_y+inset, 
        end_x-inset, end_y-inset, 'white')
    
if __name__ == '__main__':
    main()

# %%
from graphics import Canvas
import random

CANVAS_WIDTH = 450
CANVAS_HEIGHT = 300

def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    # TODO, your code here
    
    left_x = 0
    top_y = 0
    right_x = CANVAS_WIDTH
    bottom_y = CANVAS_HEIGHT / 2
    color = "red"

    rect = canvas.create_rectangle(left_x, top_y, right_x, bottom_y, color)

if __name__ == '__main__':
    main()

# %%
from graphics import Canvas

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 200
BOX_SIZE = 80

def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    for i in range(5):
        left_x = i * BOX_SIZE
        top_y = CANVAS_HEIGHT - BOX_SIZE
        right_x = left_x + BOX_SIZE
        bottom_y = CANVAS_HEIGHT
        canvas.create_rectangle(left_x, top_y, right_x, bottom_y, "white", "black")

    canvas.mainloop()

if __name__ == "__main__":
    main()

# %%
Let's practice making graphics with lots of repeated elements. This will help us get familiar with working with multiple shapes and pixel calculations!

Make a line of boxes as shown below, such that the boxes fill the bottom of the canvas. Each box should have a width and height of BOX_SIZE, making a total of 5 boxes perfectly in line with one another:

To make each individual box visible instead of making a single rectangular box, add optional arguments to your create_rectangle(...) call. The first optional argument is the fill color (in this case "white") and the second optional argument is the outline color (in this case "black"). Calling the function when you add these should look like this:

# Creates a white rectangle 
# with a black outline
canvas.create_rectangle(
    left_x, 
    top_y, 
    right_x, 
    bottom_y, 
    "white", 
    "black"
)

You should use a for loop to create your row. As an aside: it is possible to solve this problem without a for loop, but that would defeat the point of the assignment!

for i in range(N_BOXES):

The most elegant solution is to use the value of i to compute the left_x of the current box.

Once you're done, push the "Check Correct" button.

As an extension, change CANVAS_HEIGHT to be 400 and see if you can fill the entire canvas with boxes to make a 5x5 grid of squares!

# %%
Instructions
Students in Code in Place are from 150 different countries! Wow. Let's celebrate our international class by drawing flags. To start out, one of the most straightforward flags to draw using Python graphics is the flag of Indonesia:

There is 1 shape on the canvas. Red rectangle with transparent outline starting at (0, 0) and ending at (450, 150).


The dimensions of your flag should be based off the provided constants:

# The width of the canvas
CANVAS_WIDTH = 450
# The height of the canvas
CANVAS_HEIGHT = 300

To draw the Indonesian flag all you need to do is to draw a single red rectangle which covers the top half of the graphics canvas. You don't need to draw the white stripe, the canvas is white by default.

Recall the graphics method for drawing a colored rectangle:

# Draws a rectangle with specified color
rect = canvas.create_rectangle(
    left_x, 
    top_y, 
    right_x, 
    bottom_y,
    color
)

Once you have drawn the Indonesian flag, push the "check correct" button underneath the canvas to get it graded.

After that, feel free to get creative. Consider making up your own flag! Can you think of a design that would represent your friends, family, or a group that doesn't have a flag?

# %%
from graphics import Canvas
import random

CANVAS_WIDTH = 450
CANVAS_HEIGHT = 300
BRICKS_IN_BASE = 14
BRICK_WIDTH = 30
BRICK_HEIGHT = 12
def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    

    # calculating the initial width
    initial_width_space = CANVAS_WIDTH - (BRICKS_IN_BASE * BRICK_WIDTH)
    initial_width_space  = initial_width_space / 2

    curr_width = initial_width_space
    curr_bricks = BRICKS_IN_BASE 
    curr_height = CANVAS_HEIGHT
    brick_space = 0
    count = 0
    while curr_bricks > 0:
        # calculate space of one brick of each line
        brick_space = int((BRICK_WIDTH / 2) * count)
        
        curr_width += brick_space
        rect_blank(brick_space,canvas) # brick space at start
        
        for i in range(curr_bricks):
            rect = canvas.create_rectangle(curr_width, curr_height, (curr_width + BRICK_WIDTH), (curr_height - BRICK_HEIGHT), "red", "black" )
            curr_width += BRICK_WIDTH
            rect_blank(brick_space,canvas) # brick space at end
            curr_bricks -= 1
            curr_height -= BRICK_HEIGHT
            curr_width = initial_width_space
            count += 1
    print("done!")

def rect_blank(brick_space, canvas):
    rect_space = canvas.create_rectangle(0,0, brick_space, BRICK_HEIGHT, "white")
    

            





    # rect = canvas.create_rectangle(

    # )
    
    

if __name__ == '__main__':
    main()

# %%
Docs

Graphics
Create a canvas of size width, height. Returns the canvas so that you can call canvas methods on it.

canvas = Canvas(width, height)
Don't forget to import the Canvas function

from graphics import Canvas



Create Shapes
The following methods can be called on a canvas to create different shapes:


Rectangle

Create a new rectangle defined by the points (left_x,top_y) and (right_x,bottom_y). 

First optional parameter is the color of the rectangle. 

Second optional parameter is the outline color of the rectangle.

Returns the object id of the new rectangle.

# Black rectangle
rect = canvas.create_rectangle(
    left_x, 
    top_y, 
    right_x, 
    bottom_y
)

# Filled rectangle
rect = canvas.create_rectangle(
    left_x, 
    top_y, 
    right_x, 
    bottom_y,
    color
)

# Rectangle with an outline
rect = canvas.create_rectangle(
    left_x, 
    top_y, 
    right_x, 
    bottom_y,
    color,
    outline
)

Oval

Create an oval inscribed in the bounding box defined by (left_x,top_y) and (right_x,bottom_y). First optional parameter is the color of the oval. 

Second optional parameter is the outline color of the oval.

Returns the object id of the new circle.

# Black oval
oval = canvas.create_oval(
    left_x, 
    top_y, 
    right_x, 
    bottom_y
)

# Filled oval
oval = canvas.create_oval(
    left_x, 
    top_y, 
    right_x, 
    bottom_y,
    color
)

# Oval with an outline
oval = canvas.create_oval(
    left_x, 
    top_y, 
    right_x, 
    bottom_y,
    color,
    outline
)

Line

Create a new line connecting (x1, y1) to (x2, y2). 

Optional extra parameter is the color of the line. 

Returns the object id of the new line.

# Black line
line = canvas.create_line(
    x1, y1, 
    x2, y2
)

# Line with color
line = canvas.create_line(
    x1, y1, 
    x2, y2, 
    color
)

Text

Draw the given text on the screen anchored at the given (x, y) location.

Optional parameter: font, 

Optional parameter: font_size

Optional parameter: color

# Text drawn at (x,y)
obj = canvas.create_text(
    x, 
    y, 
    text
)

# "My first text!"
canvas.create_text(
    x, 
    y, 
    text = 'My first text!',
    font = 'Arial', 
    font_size = 50, 
    color ='blue'
)

Image

First upload an image to your project (see the files tab). Then you can add that image to the canvas.

# Image at a location
image = canvas.create_image(
    left_x, 
    top_y, 
    filename
)

# Image with size
image = canvas.create_image_with_size(
    left_x, 
    top_y, 
    width, 
    height, 
    filename
)

Polygon

Create a new polygon by passing through a series of points. Because coordinates is a list of arguments, a call to the function would look like this: polygon = canvas.create_polygon(10, 10, 20, 20, 10, 20, color="RED", outline="BLACK"). This would create a triangle with points at (10, 10), (20, 20), and (10, 20).

# Create a polygon
polygon = canvas.create_polygon(
    coordinates, 
    color, 
    outline
)

# Example triangle
polygon = canvas.create_polygon(
   10, 10, 20, 20, 10, 20,
   color="red",
)

Modify Shapes

The following methods can be called on a canvas to modify a given shape:


Move the object with given id dx pixels to the right and dy pixels down.

canvas.move(objectId, dx, dy)

Move the object with given id the the location (new_x, new_y)

canvas.moveto(objectId, new_x, new_y)

Delete an object and remove it from the canvas.

canvas.delete(objectId)

Set whether a shape is visible. If is_hidden is true, the object will become hidden, if it is false, it will become unhidden.

canvas.set_hidden(objectId, is_hidden)

Changes the text content of the text object referenced by objectId to the string passed in as new_text

canvas.change_text(objectId, new_text)

Canvas Helpers

The following methods can be called on a canvas:


Returns the current x coordinate of the mouse, measured in pixels from the left of the canvas.

x = canvas.get_mouse_x()

Returns the current y coordinate of the mouse, measured in pixels from the top of the canvas.

y = canvas.get_mouse_y()

Returns the location of the last mouse click since this function was called. Returns null if there have been no clicks

click = canvas.get_last_click()

Returns the last key which was pressed by the user on the keyboard. Returns null if there have been no key presses.

key = canvas.get_last_key_press()

Returns a list of objects which overlap with the rectangular region defined by (left_x,top_y) and (right_x,bottom_y)

objs = canvas.find_overlapping(
    left_x, 
    top_y, 
    right_x, 
    bottom_y
)

Clears all objects from the canvas.

canvas.clear()

Returns the left most x coordinate of images, lines, rectangles, and ovals.

left_x = canvas.get_left_x(obj)

Returns the top most y coordinate of images, lines, rectangles, and ovals.

top_y = canvas.get_top_y(obj)

Returns the width of the object with the specified objectId on the canvas.

width = canvas.get_object_width(obj)

Returns the height of the object with the specified objectId on the canvas.

height = canvas.get_object_height(obj)

Sets the fill color of the object with the specified objectId on the canvas to the specified color. The color parameter can be any valid CSS color value.

canvas.set_color(obj, color)

Sets the outline color of the object with the specified objectId on the canvas to the specified color. The color parameter can be any valid CSS color value.

canvas.set_outline_color(obj, color)

Pauses the execution of the program until the user clicks somewhere on the canvas. Returns the location of the mouse click as an object with 'x' and 'y' properties, representing the coordinates of the mouse click on the canvas.

canvas.wait_for_click()

Returns an list of new mouse clicks since this function was last called. Each element in the list is an object with 'x' and 'y' properties, representing the coordinates of the mouse click on the canvas. Returns an empty list if there have been no new clicks.

clicks = canvas.get_new_mouse_clicks()

Returns an list of new key presses since this function was last called. Each element in the list is a string representing the key pressed by the user. Returns an empty list if there have been no new key presses.

keys = canvas.get_new_key_presses()

Returns an list of coordinates of the object that is formatted as [left_x, top_y]

coords = canvas.coords(objectId)

Thats all folks!

# %%
pip install matplotlib
import matplotlib.pyplot as plt
# Import the library
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a line plot
plt.plot(x, y)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')

# Display the plot
plt.show()

# %%
# Customizing the plot
plt.plot(x, y, color='red', linestyle='--', marker='o', label='Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Customized Line Plot')
plt.legend()  # Show legend
plt.grid(True)  # Show grid
plt.show()

# %%
import tkinter as tk


CANVAS_WIDTH = 450
CANVAS_HEIGHT = 300

def main():
    root = tk.Tk()
    canvas = tk.Canvas(root, width=CANVAS_WIDTH, height=CANVAS_HEIGHT)
    canvas.pack()
    
    for i in range(0, 5):
        canvas.create_oval(i*20, i*20, i*20+20, i*20+20)

    root.mainloop()

if __name__ == '__main__':
    main()

# %%
how to work with python graphics
ChatGPT
Working with graphics in Python can be accomplished using various libraries, but one of the most popular ones is called matplotlib. Here's a basic guide on how to get started with matplotlib for creating graphics in Python:

Install Matplotlib: If you haven't already installed matplotlib, you can do so using pip, the Python package manager. Open your command line or terminal and run:

Copy code
pip install matplotlib
Import Matplotlib: In your Python script, import the matplotlib.pyplot module, which provides a MATLAB-like plotting framework:

python
Copy code
import matplotlib.pyplot as plt
Creating Basic Plots: Matplotlib provides various functions for creating different types of plots like line plots, scatter plots, bar plots, histograms, etc. Here's an example of a simple line plot:

python
Copy code
# Import the library
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a line plot
plt.plot(x, y)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')

# Display the plot
plt.show()
Customizing Plots: You can customize your plots by adding labels, titles, legends, changing colors, line styles, marker styles, etc.

python
Copy code
# Customizing the plot
plt.plot(x, y, color='red', linestyle='--', marker='o', label='Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Customized Line Plot')
plt.legend()  # Show legend
plt.grid(True)  # Show grid
plt.show()
Saving Plots: You can save your plots to a file using the savefig() function.

python
Copy code
# Save the plot
plt.savefig('plot.png')
Exploring Further: matplotlib is a vast library with many capabilities. You can explore the official documentation and various tutorials available online to learn more about advanced plotting techniques and features.

Remember, matplotlib is just one of many Python libraries for graphics. Depending on your specific needs and preferences, you might also want to explore other libraries like seaborn, plotly, bokeh, etc. Each has its own strengths and use cases.

what about using canva
ChatGPT
If you're referring to using Canva, the graphic design platform, with Python, there isn't a direct integration or API provided by Canva specifically for that purpose. Canva is primarily a web-based application that offers a user-friendly interface for designing graphics, presentations, and other visual content.

However, you can still use Python to work with graphics and incorporate Canva designs into your workflow in a couple of ways:

Automated Design Export: If you create designs in Canva that need to be exported in bulk or on a regular basis, you can use Python to automate the export process. Canva provides a feature called "Brand Kit" that allows you to define brand colors, fonts, and logos, which can be applied to designs. You could create your designs using Canva's web interface, then use Python scripts along with Canva's API (if available) or web scraping techniques to download the designs automatically.

Data Visualization: Python offers numerous libraries for data visualization, as mentioned earlier (e.g., matplotlib, seaborn, plotly). You can use these libraries to create charts, graphs, and other visualizations directly within Python, without relying on external tools like Canva. While Canva provides a more general-purpose design tool, Python's libraries excel in creating data-driven visualizations, especially for scientific, statistical, or business data.

Integration with Canva API (if available): At the time of my last update, Canva did not offer a public API for direct integration with external applications. However, if Canva releases an API in the future, you could potentially use Python to interact with it and automate certain tasks or integrate Canva's functionality into your own applications.

In summary, while you can't directly use Canva within Python, you can leverage Python for tasks such as automating design exports, creating data visualizations, or potentially integrating with Canva's API if it becomes available.

what about this
from graphics import Canvas
import random

CANVAS_WIDTH = 450
CANVAS_HEIGHT = 300

def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    for i in range(0, 5):
        canvas.create_oval(i*20, i*20, i*20+20, i*20+20)
    

if __name__ == '__main__':
    main()
ChatGPT
It seems like you're trying to create a simple graphical application using a library named "graphics" that provides a Canvas object. However, as of my last update, there isn't a widely known Python library named "graphics" with a Canvas object.

If you're looking for a library to work with graphics in Python, you might want to consider alternatives like Tkinter, PyQt, or Pygame. These libraries provide functionality for creating graphical user interfaces (GUIs) and drawing graphics on a canvas.

Here's a modified version of your code using Tkinter, a commonly used GUI library in Python:

python
Copy code
import tkinter as tk

CANVAS_WIDTH = 450
CANVAS_HEIGHT = 300

def main():
    root = tk.Tk()
    canvas = tk.Canvas(root, width=CANVAS_WIDTH, height=CANVAS_HEIGHT)
    canvas.pack()
    
    for i in range(0, 5):
        canvas.create_oval(i*20, i*20, i*20+20, i*20+20)

    root.mainloop()

if __name__ == '__main__':
    main()
This code creates a window with a canvas using Tkinter and draws five ovals on the canvas. You can run this code, and it should display the graphical output with the ovals drawn on the canvas.

is there anything to install before importing import tkinter as tk
ChatGPT
In most cases, you won't need to install anything extra to use Tkinter because it is included with Python's standard library. However, if for some reason Tkinter is not available, you might need to install it separately.

For Windows and macOS, Tkinter should be included with your Python installation by default. However, for some Linux distributions, Tkinter might be provided as a separate package. If you're using a Linux distribution and Tkinter is not available by default, you can typically install it using your package manager. For example, on Ubuntu or Debian-based systems, you can install Tkinter with the following command:

arduino
Copy code
sudo apt-get install python3-tk
Replace python3-tk with python-tk if you're using Python 2.x.

After installing Tkinter, you should be able to import it using import tkinter as tk in your Python scripts without any issues.

what about pip
ChatGPT
If you need to install Tkinter using pip, you might run into an issue because Tkinter is typically bundled with Python installations, and pip doesn't handle it as a separate package. Tkinter is a Python interface to the Tk GUI toolkit and is a standard part of Python.

If you're using a Python distribution where Tkinter is not available by default or if you encounter any issues with Tkinter, it's recommended to reinstall Python from the official Python website or use a Python distribution like Anaconda that includes Tkinter by default.

To ensure Tkinter is available, you can simply import it in your Python script:

python
Copy code
import tkinter as tk
If this import statement executes without any errors, then Tkinter is installed and available for use in your Python environment. If you encounter an ImportError, it likely means that Tkinter is not properly installed or configured in your Python environment. In that case, you may need to reinstall Python or troubleshoot your Python installation to ensure Tkinter is available.

thanks
ChatGPT
You're welcome! If you have any more questions or need further assistance, feel free to ask. Happy coding!

# %%
# for linux distribution
sudo apt-get install python3-tk
from graphics import Canvas
is the graphics part of python package or it is install separately using pip
ChatGPT
The statement from graphics import Canvas suggests that you're trying to import a module named Canvas from a package named graphics. However, there isn't a standard Python package called graphics that provides a Canvas module.

If you found this code in a tutorial or example, it's possible that it's using a custom library or a third-party library named graphics. In that case, you'll need to install this library separately using pip if it's not included with Python by default.

To install a Python package using pip, you can use the following command:

Copy code
pip install graphics-library-name
Replace graphics-library-name with the actual name of the library you're trying to install.

If you're not sure which library provides the Canvas module you're trying to import, you may need to refer to the documentation or source where you found this code to determine the correct library name and installation instructions.

such as 
pip install graphics-Canvas
ChatGPT
If you are trying to install a Python package named graphics-Canvas, you would use pip in the following way:

bash
Copy code
pip install graphics-Canvas
However, please note that this assumes that there is indeed a package named graphics-Canvas available on the Python Package Index (PyPI). In reality, this specific package might not exist, or its name might be different.

If you're trying to use a specific graphics library with a Canvas module, it's crucial to find the correct name of that library and use that name for installation. You can typically find the correct package name and installation instructions on the library's documentation page or the source where you found the code. If you're unsure about the library's name, you might need to do some research or clarify with the source of the code.
